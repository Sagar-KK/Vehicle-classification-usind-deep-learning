# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2



DATADIR = "C:/Users/Acer/Desktop/project_images"
CATEGORIES=["bikes","buses","cars","cycles"]

for category in CATEGORIES:
    path=os.path.join(DATADIR,category)#path to one of the class ie. bikes,buses,cars,cycles
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array,cmap="gray")
        plt.show()
        break
    break

# %%
print(img_array.shape)
# Out:
# (409, 615)

# %%
image_size=100
new_array=cv2.resize(img_array,(image_size,image_size))
plt.imshow(new_array,cmap="gray")
plt.show()

# %%
training_data=[]
def create_training_data():
    for category in CATEGORIES:
        path=os.path.join(DATADIR,category)#path to one of the class ie. bikes,buses,cars,cycles
        class_num=CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                new_array=cv2.resize(img_array,(image_size,image_size))
                training_data.append([new_array,class_num])
            except Exception as e:
                pass
            
create_training_data()

# %%
plt.imshow(training_data[][0],cmap="gray")

# %%
sample_data=training_data[885+843+836]

# %%
sample_data[1]
# Out:
# 2

# %%
print(len(training_data))
# Out:
# 3241

# %%
import random
random.shuffle(training_data)

for sample in training_data[:10]:
    print(sample[1])
# Out:
# 2
# 3
# 3
# 2
# 2
# 0
# 0
# 0
# 2
# 2

# %%
X=[]
y=[]

# %%
for features,label in training_data:
    X.append(features)
    y.append(label)
X=np.array(X).reshape(-1,image_size,image_size,1)

# %%
import pickle


pickle_out=open("X.pickle","wb")
pickle.dump(X,pickle_out)
pickle_out.close()

pickle_out=open("y.pickle","wb")
pickle.dump(y,pickle_out)
pickle_out.close()

# %%
pickle_in=open("X.pickle","rb")
X=pickle.load(pickle_in)

# %%
X[1]
y[1]
# Out:
# 3
